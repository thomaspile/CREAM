# %%
import pandas as pd
import numpy as np
import sys
from datetime import datetime
from matplotlib import pyplot as plt
import plotly.graph_objects as go

# %%
df_calls = pd.read_csv('../cotton/data/df_cotton_calls.csv')
df_prices = pd.read_csv('../cotton/data/df_cotton_prices.csv').rename(columns={'a_index':'price'})

# %%
df_prices.plot(x='date', y='price')
# Out:
# <Axes: xlabel='date'>

# %%
# Overwrite prices from 30 days prior to the date at which there is an error in the data, up till the end of the problem.
# Need to overwrite with np.nan rather than dropping the rows so that the time integrigty of the outcome variables during 
# these is maintained. Otherwise prices from beyond the period will be brought forward into the outcomes prior to the period
df_prices['price'] = np.where((df_prices.date < '2011-05-10') | (df_prices.date > '2011-07-29'), df_prices['price'], np.nan)

# %%
df_prices.plot(x='date', y='price')
# Out:
# <Axes: xlabel='date'>

# %%
var = 'unfixed_sale'

# %%
df_calls['unfixed_net'] = df_calls['unfixed_purchase'] - df_calls['unfixed_sale']
df_calls['report_month'] = pd.to_datetime(df_calls['date']).dt.month
df_calls['report_year'] = pd.to_datetime(df_calls['date']).dt.isocalendar().year
df_calls['futures_datetime'] = pd.to_datetime(df_calls['month'])
df_calls['futures_month'] = pd.to_datetime(df_calls['month']).dt.month
df_calls['futures_year'] = pd.to_datetime(df_calls['month']).dt.isocalendar().year

df_calls['futures_month_ranked'] = df_calls.groupby('date')['futures_datetime'].rank(method='dense')

df_calls['season'] = np.where(df_calls['report_year'] == df_calls['futures_year'], 'season1',
                       np.where(df_calls['report_year'] + 1 == df_calls['futures_year'], 'season2',
                          np.where(df_calls['report_year'] + 2 == df_calls['futures_year'], 'season3', 'season_OTHER')))
                          
df_calls['futures_month'] = np.where(df_calls['futures_month'] < 10, 
                                     '0' + df_calls['futures_month'].astype(str), 
                                     df_calls['futures_month'].astype(str))
df_calls['futures_reference'] = df_calls['season'] + '_' + df_calls['futures_month']

df_calls = df_calls[df_calls.season.isin(['season1', 'season2'])]

# %%
def build_outcomes(df_in, var, datetime_var, n_forward_looks = [1, 2, 3, 5, 10]):

    df = df_in.copy()
    for n in n_forward_looks:
        df[f'max_{n}_forward'] = (df.iloc[::-1]
                .rolling(n, on=datetime_var, min_periods=0)[var]
                .max()
                .iloc[::-1])
        
        df[f'mean_{n}_forward'] = (df.iloc[::-1]
                .rolling(n, on=datetime_var, min_periods=0)[var]
                .mean()
                .iloc[::-1])
        
        df[f'value_delta_mean_{n}_forward'] = df[f'mean_{n}_forward'] - df[var]
        df[f'value_delta_max_{n}_forward'] = df[f'max_{n}_forward'] - df[var]
        
        df[f'pct_delta_mean_{n}_forward'] = (df[f'mean_{n}_forward'] / df[var]) - 1
        df[f'pct_delta_max_{n}_forward'] = (df[f'max_{n}_forward'] / df[var]) - 1   
        
        df[f'mean_rise_{n}_forward'] = np.where(df[f'pct_delta_mean_{n}_forward'] > 0, 1, 0)
        df[f'max_rise_{n}_forward'] = np.where(df[f'pct_delta_max_{n}_forward'] > 0, 1, 0)
        
        # These values are highly correlated with calls variables, because they are higly correlted with the price at the given time.
        # The high correlation, along with price itself, only tells us that there are many unfixed purchases when prices are low and
        # fewer when prices are high. If we were to use the on-call variables which correlate highly with these, we would just be learning 
        # that when there are high unfixed calls, the price is likely to be low, rather than learning whther the price is likely to
        # increase from here
        df = df.drop(columns=[f'max_{n}_forward', f'mean_{n}_forward'])

    return df

def add_column_cyclical_features(df, datetime_var, period, start_num=0):
    
    values = 2 * np.pi * (df[datetime_var] - start_num) / period
    kwargs = {f'sin_{datetime_var}': lambda x: np.sin(values),
              f'cos_{datetime_var}': lambda x: np.cos(values)}
    
    return df.assign(**kwargs)

# %%
var
# Out:
# 'unfixed_sale'

# %%
df_calls_pivot = df_calls.pivot_table(index='date', columns='futures_reference', 
                                      values=var, aggfunc='first')\
                         .reset_index()
df_weekly_averages = df_calls.pivot_table(index='report_week', columns='futures_reference', 
                                          values=var, aggfunc='mean')\
                             .reset_index()
df_weekly_averages = df_weekly_averages.rename(columns={x:'report_week_mean_'+x for x in df_weekly_averages.columns if 'season' in x})

df_yearweek_total_calls = df_calls.groupby(['date', 'report_year', 'report_week'])[var].sum()\
                                  .reset_index().rename(columns={var:'report_week_total_calls'})
df_weekly_total_calls_averages = df_yearweek_total_calls.groupby('report_week').report_week_total_calls.mean()\
                                                        .reset_index().rename(columns={'report_week_total_calls':'report_week_mean_total_calls'})

df_numbered_months = df_calls.pivot_table(index='date', columns='futures_month_ranked', values=var, aggfunc='first').reset_index()
df_numbered_months = df_numbered_months.rename(columns={x: 'calls_month_' + str(int(x)) + '_away' for x in df_numbered_months.columns if x != 'date'})

# %%
df_numbered_months
# Out:
# futures_month_ranked        date  calls_month_1_away  calls_month_2_away  \
# 0                     2001-02-02              2108.0              6764.0
# 1                     2001-02-09              1616.0              5927.0
# 2                     2001-02-16               943.0              5252.0
# 3                     2001-02-23                57.0              3967.0
# 4                     2001-03-02                 6.0              3113.0
# ...                          ...                 ...                 ...
# 1210                  2024-05-10                 0.0             16052.0
# 1211                  2024-05-17             13769.0                 0.0
# 1212                  2024-05-24             10438.0                 0.0
# 1213                  2024-05-31              9376.0                 0.0
# 1214                  2024-06-07              4739.0                 0.0
#
# futures_month_ranked  calls_month_3_away  calls_month_4_away  \
# 0                                16222.0              1518.0
# 1                                15570.0              1525.0
# 2                                15150.0              1538.0
# 3                                13853.0              1377.0
# 4                                12639.0              1253.0
# ...                                  ...                 ...
# 1210                                 0.0             22100.0
# 1211                             23663.0              6690.0
# 1212                             25272.0              7305.0
# 1213                             27475.0              7557.0
# 1214                             32241.0              8035.0
#
# futures_month_ranked  calls_month_5_away  calls_month_6_away  \
# 0                                 3684.0              9226.0
# 1                                 3809.0              9778.0
# 2                                 4451.0             10614.0
# 3                                 4924.0             11198.0
# 4                                 4934.0             12014.0
# ...                                  ...                 ...
# 1210                              6638.0              2899.0
# 1211                              2894.0              2614.0
# 1212                              4015.0              2632.0
# 1213                              4338.0              3026.0
# 1214                              4565.0              3520.0
#
# futures_month_ranked  calls_month_7_away  calls_month_8_away
# 0                                 3322.0              5062.0
# 1                                 3397.0              5488.0
# 2                                 3777.0              6339.0
# 3                                 4092.0              6779.0
# 4                                 4504.0              7528.0
# ...                                  ...                 ...
# 1210                              2151.0               687.0
# 1211                               828.0                 NaN
# 1212                               854.0                 NaN
# 1213                               955.0                 NaN
# 1214                              1167.0                 NaN
#
# [1215 rows x 9 columns]

# %%
df_weekly_averages = add_column_cyclical_features(df_weekly_averages, 'report_week', 52, 1)

fig1 = go.Figure()
fig1.add_trace(go.Scatter(
     x=df_weekly_averages['sin_report_week'],
     y=df_weekly_averages['cos_report_week'],
     name='Sin vs Cos for Report Week',
     mode='lines+markers+text',
     text=["<b>" + str(i) + "</b>" for i in range(0,60)],
     showlegend=False
 ))
fig1.update_traces(textfont_size=16, marker=dict(size=22))
fig1.update_layout(hovermode="x", xaxis_title="Sin of Week", yaxis_title="Cos of Week", 
                   yaxis = dict(scaleanchor = "x", scaleratio = 1), width=800, height=800, 
                   legend=dict(orientation="h", x=0.05), title="Sin/Cos Encoding of Report Week", title_x=0.5)
fig1.show()

# %%
df_features = df_calls_pivot.merge(df_yearweek_total_calls, on='date', how='left')\
                            .merge(df_weekly_averages, on='report_week', how='left')\
                            .merge(df_weekly_total_calls_averages, on='report_week', how='left')\
                            .merge(df_numbered_months, on='date', how='left')

# df_features['report_week_total_calls_divergence'] = df_features['report_week_total_calls'] - df_features['report_week_mean_total_calls'] 

for col in [x for x in df_calls_pivot.columns if x.startswith('season')]:
    df_features[col + '_divergence'] = df_features[col] - df_features['report_week_mean_' + col]

drop_cols = [x for x in df_features.columns if x.startswith('report_week_mean')]  
df_features = df_features.drop(columns=drop_cols)
df_features = df_features.sort_values(['report_year', 'report_week'])

# %%
df_outcomes = df_prices[['date', 'price']]
df_outcomes = build_outcomes(df_outcomes, 'price', 'date', n_forward_looks = [30, 15, 7])

# %%
df_model = df_features.merge(df_outcomes, on='date', how='left')
df_model['report_month'] = pd.to_datetime(df_model['date']).dt.month

# %%
df_model.to_csv('../cotton/data/df_on_call_mset.csv', index=False)

# %%
season_vars = [x for x in df_model.columns if x.startswith('season')]
correlation_vars = [x for x in df_model.columns if x not in ['report_year', 'date', 'price'] + season_vars]
outcome_vars = [x for x in df_outcomes if x not in ['date', 'price']]
df_corr = df_model[correlation_vars].corr()
df_corr = df_corr.drop(outcome_vars, axis=0)[outcome_vars].sort_values('value_delta_mean_30_forward')
df_corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_49973_row0_col0, #T_49973_row0_col1, #T_49973_row0_col2, #T_49973_row0_col3, #T_49973_row0_col4, #T_49973_row0_col5, #T_49973_row0_col6, #T_49973_row0_col7, #T_49973_row0_col8, #T_49973_row0_col9, #T_49973_row0_col10, #T_49973_row0_col15, #T_49973_row2_col12, #T_49973_row3_col11, #T_49973_row3_col14, #T_49973_row3_col16, #T_49973_row3_col17, #T_49973_row7_col13 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_49973_row0_col11 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_49973_row0_col12, #T_49973_row1_col9 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_49973_row0_col13 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_49973_row0_col14, #T_49973_row6_col17 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_49973_row0_col16, #T_49973_row3_col5 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_49973_row0_col17, #T_49973_row6_col5 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_49973_row1_col0, #T_49973_row3_col4 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_49973_row1_col1, #T_49973_row1_col6 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_49973_row1_col2 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_49973_row1_col3 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_49973_row1_col4 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_49973_row1_col5 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_49973_row1_col7 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_49973_row1_col8, #T_49973_row2_col8 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_49973_row1_col10, #T_49973_row12_col3 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_49973_row1_col11 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_49973_row1_col12 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_49973_row1_col13, #T_49973_row1_col16 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_49973_row1_col14 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_49973_row1_col15, #T_49973_row5_col13 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_49973_row1_col17 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_49973_row2_col0 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_49973_row2_col1, #T_49973_row11_col16 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_49973_row2_col2, #T_49973_row3_col10 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_49973_row2_col3, #T_49973_row2_col11 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_49973_row2_col4 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_49973_row2_col5 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_49973_row2_col6 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_49973_row2_col7, #T_49973_row5_col12 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_49973_row2_col9 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_49973_row2_col10 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_49973_row2_col13 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_49973_row2_col14, #T_49973_row7_col1, #T_49973_row12_col15 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_49973_row2_col15 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_49973_row2_col16 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_49973_row2_col17, #T_49973_row12_col1 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_49973_row3_col0 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_49973_row3_col1, #T_49973_row4_col0, #T_49973_row7_col3, #T_49973_row9_col15 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_49973_row3_col2 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_49973_row3_col3 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_49973_row3_col6, #T_49973_row6_col0, #T_49973_row7_col14 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_49973_row3_col7 {
#   background-color: #f3c8b2;
#   color: #000000;
# }
# #T_49973_row3_col8 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_49973_row3_col9, #T_49973_row3_col13, #T_49973_row4_col3, #T_49973_row4_col16 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_49973_row3_col12, #T_49973_row5_col16 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_49973_row3_col15 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_49973_row4_col1 {
#   background-color: #f7b396;
#   color: #000000;
# }
# #T_49973_row4_col2, #T_49973_row8_col6 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_49973_row4_col4 {
#   background-color: #f7ba9f;
#   color: #000000;
# }
# #T_49973_row4_col5 {
#   background-color: #d24b40;
#   color: #f1f1f1;
# }
# #T_49973_row4_col6, #T_49973_row4_col8 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_49973_row4_col7 {
#   background-color: #f7af91;
#   color: #000000;
# }
# #T_49973_row4_col9, #T_49973_row5_col10, #T_49973_row6_col6 {
#   background-color: #f7b599;
#   color: #000000;
# }
# #T_49973_row4_col10 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_49973_row4_col11 {
#   background-color: #ca3b37;
#   color: #f1f1f1;
# }
# #T_49973_row4_col12, #T_49973_row6_col7 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_49973_row4_col13, #T_49973_row9_col9 {
#   background-color: #f08b6e;
#   color: #f1f1f1;
# }
# #T_49973_row4_col14 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_49973_row4_col15, #T_49973_row8_col10 {
#   background-color: #f29274;
#   color: #f1f1f1;
# }
# #T_49973_row4_col17 {
#   background-color: #ba162b;
#   color: #f1f1f1;
# }
# #T_49973_row5_col0 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_49973_row5_col1, #T_49973_row5_col15 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_49973_row5_col2, #T_49973_row7_col2, #T_49973_row9_col6 {
#   background-color: #f29072;
#   color: #f1f1f1;
# }
# #T_49973_row5_col3 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_49973_row5_col4, #T_49973_row11_col2 {
#   background-color: #e9785d;
#   color: #f1f1f1;
# }
# #T_49973_row5_col5, #T_49973_row5_col8, #T_49973_row11_col4, #T_49973_row11_col5 {
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_49973_row5_col6 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_49973_row5_col7, #T_49973_row7_col7 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_49973_row5_col9 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_49973_row5_col11, #T_49973_row11_col12 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_49973_row5_col14 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_49973_row5_col17, #T_49973_row9_col8 {
#   background-color: #f7ad90;
#   color: #000000;
# }
# #T_49973_row6_col1 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_49973_row6_col2, #T_49973_row11_col11 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_49973_row6_col3 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_49973_row6_col4 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_49973_row6_col8, #T_49973_row11_col7 {
#   background-color: #f5c1a9;
#   color: #000000;
# }
# #T_49973_row6_col9 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_49973_row6_col10, #T_49973_row9_col11 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_49973_row6_col11 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_49973_row6_col12 {
#   background-color: #e57058;
#   color: #f1f1f1;
# }
# #T_49973_row6_col13 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_49973_row6_col14 {
#   background-color: #dd5f4b;
#   color: #f1f1f1;
# }
# #T_49973_row6_col15 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_49973_row6_col16 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_49973_row7_col0, #T_49973_row7_col8 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_49973_row7_col4 {
#   background-color: #ea7b60;
#   color: #f1f1f1;
# }
# #T_49973_row7_col5 {
#   background-color: #f5c2aa;
#   color: #000000;
# }
# #T_49973_row7_col6 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_49973_row7_col9, #T_49973_row8_col16 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_49973_row7_col10, #T_49973_row7_col11, #T_49973_row9_col10 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_49973_row7_col12 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_49973_row7_col15 {
#   background-color: #7a9

# %%
correlations = []
for month in df_model['report_month'].unique():
    df = df_model[df_model['report_month'] == month]
    df_corr = df[correlation_vars].corr()
    df_corr = df_corr.drop(outcome_vars, axis=0)[outcome_vars].sort_values('value_delta_mean_30_forward')
    df_corr['month'] = month
    correlations.append(df_corr)

# %%
correlations[0]
# Out:
#                                     value_delta_mean_30_forward  \
# calls_month_6_away                                    -0.080921
# report_week                                           -0.015728
# calls_month_1_away                                    -0.012456
# calls_month_8_away                                    -0.012077
# sin_report_week                                       -0.009644
# cos_report_week                                        0.022245
# calls_month_7_away                                     0.038297
# calls_month_4_away                                     0.081053
# calls_month_2_away                                     0.104683
# calls_month_5_away                                     0.118187
# report_week_total_calls                                0.129085
# report_week_total_calls_divergence                     0.130653
# calls_month_3_away                                     0.228711
# report_month                                                NaN
#
#                                     value_delta_max_30_forward  \
# calls_month_6_away                                   -0.030978
# report_week                                          -0.038720
# calls_month_1_away                                    0.067707
# calls_month_8_away                                    0.263381
# sin_report_week                                      -0.037600
# cos_report_week                                       0.039895
# calls_month_7_away                                    0.147116
# calls_month_4_away                                   -0.034933
# calls_month_2_away                                    0.252082
# calls_month_5_away                                    0.342576
# report_week_total_calls                               0.325700
# report_week_total_calls_divergence                    0.327089
# calls_month_3_away                                    0.426333
# report_month                                               NaN
#
#                                     pct_delta_mean_30_forward  \
# calls_month_6_away                                  -0.141920
# report_week                                          0.015437
# calls_month_1_away                                  -0.013308
# calls_month_8_away                                  -0.211672
# sin_report_week                                      0.024958
# cos_report_week                                     -0.004048
# calls_month_7_away                                  -0.081592
# calls_month_4_away                                   0.159046
# calls_month_2_away                                   0.088601
# calls_month_5_away                                   0.091358
# report_week_total_calls                              0.079026
# report_week_total_calls_divergence                   0.081589
# calls_month_3_away                                   0.167213
# report_month                                              NaN
#
#                                     pct_delta_max_30_forward  \
# calls_month_6_away                                 -0.077116
# report_week                                         0.039751
# calls_month_1_away                                  0.041044
# calls_month_8_away                                  0.069441
# sin_report_week                                     0.042840
# cos_report_week                                    -0.034642
# calls_month_7_away                                 -0.024818
# calls_month_4_away                                  0.109015
# calls_month_2_away                                  0.144863
# calls_month_5_away                                  0.294763
# report_week_total_calls                             0.202033
# report_week_total_calls_divergence                  0.205208
# calls_month_3_away                                  0.250520
# report_month                                             NaN
#
#                                     mean_rise_30_forward  max_rise_30_forward  \
# calls_month_6_away                              0.026534            -0.074408
# report_week                                     0.126288             0.165375
# calls_month_1_away                             -0.093453            -0.076924
# calls_month_8_away                             -0.111563            -0.089962
# sin_report_week                                 0.138175             0.168495
# cos_report_week                                -0.111444            -0.160252
# calls_month_7_away                              0.003379            -0.046384
# calls_month_4_away                              0.151751             0.071175
# calls_month_2_away                              0.161596             0.104160
# calls_month_5_away                              0.141986             0.080163
# report_week_total_calls                         0.127529             0.056896
# report_week_total_calls_divergence              0.136080             0.065373
# calls_month_3_away                              0.179484             0.099538
# report_month                                         NaN                  NaN
#
#                                     value_delta_mean_15_forward  \
# calls_month_6_away                                    -0.058247
# report_week                                            0.058842
# calls_month_1_away                                    -0.060672
# calls_month_8_away                                     0.090964
# sin_report_week                                        0.061523
# cos_report_week                                       -0.055768
# calls_month_7_away                                     0.049990
# calls_month_4_away                                     0.117556
# calls_month_2_away                                     0.037133
# calls_month_5_away                                     0.060862
# report_week_total_calls                                0.068428
# report_week_total_calls_divergence                     0.072575
# calls_month_3_away                                     0.146011
# report_month                                                NaN
#
#                                     value_delta_max_15_forward  \
# calls_month_6_away                                   -0.014731
# report_week                                           0.037791
# calls_month_1_away                                   -0.000688
# calls_month_8_away                                    0.299695
# sin_report_week                                       0.035702
# cos_report_week                                      -0.040148
# calls_month_7_away                                    0.157774
# calls_month_4_away                                    0.031923
# calls_month_2_away                                    0.138888
# calls_month_5_away                                    0.213107
# report_week_total_calls                               0.214585
# report_week_total_calls_divergence                    0.218513
# calls_month_3_away                                    0.303493
# report_month                                               NaN
#
#                                     pct_delta_mean_15_forward  \
# calls_month_6_away                                  -0.102911
# report_week                                          0.092790
# calls_month_1_away                                  -0.069843
# calls_month_8_away                                  -0.059756
# sin_report_week                                      0.098829
# cos_report_week                                     -0.084848
# calls_month_7_away                                  -0.038287
# calls_month_4_away                                   0.212378
# calls_month_2_away                                   0.047191
# calls_month_5_away                                   0.062633
# report_week_total_calls                              0.050099
# report_week_total_calls_divergence                   0.055716
# calls_month_3_away                                   0.121409
# report_month                                              NaN
#
#                                     pct_delta_max_15_forward  \
# calls_month_6_away                                 -0.046919
# report_week                                         0.144650
# calls_month_1_away                                 -0.055633
# calls_month_8_away                                  0.140673
# sin_report_week                                     0.143738
# cos_report_week                                    -0.143823
# calls_month_7_away                                  0.022222
# calls_month_4_away                                  0.184999
# calls_month_2_away                                  0.067827
# calls_month_5_away                                  0.185542
# report_week_total_calls                             0.119913
# report_week_total_calls_divergence                  0.127288
# calls_month_3_away                                  0.168125
# report_month                                             NaN
#
#                                     mean_rise_15_forward  max_rise_15_forward  \
# calls_month_6_away                             -0.073253            -0.074994
# report_week                                     0.161352             0.085384
# calls_month_1_away                             -0.108097            -0.064266
# calls_month_8_away                             -0.125698            -0.074440
# sin_report_week                                 0.167294             0.093878
# cos_report_week                                -0.151275            -0.073895
# calls_month_7_away                             -0.074126            -0.054941
# calls_month_4_away                              0.210203             0.153088
# calls_month_2_away                             -0.024170             0.096714
# calls_month_5_away                             -0.033899             0.023909
# report_week_total_calls                        -0.048720             0.044484
# report_week_total_calls_divergence             -0.042726             0.049782
# calls_month_3_away                             -0.014726             0.084121
# report_month                                         NaN                  NaN
#
#                                     value_delta_mean_7_forward  \
# calls_month_6_away                                   -0.056882
# report_week                                           0.106650
# calls_month_1_away                                   -0.061376
# calls_month_8_away                                    0.071656
# sin_report_week                                       0.101824
# cos_report_week                                      -0.111539
# calls_month_7_away                                    0.024317
# calls_month_4_away                                    0.087058
# calls_month_2_away                                    0.010549
# calls_month_5_away                                    0.029918
# report_week_total_calls                               0.027707
# report_week_total_calls_divergence                    0.031815
# calls_month_3_away                                    0.080424
# report_month                                               NaN
#
#                                     value_delta_max_7_forward  \
# calls_month_6_away                                  -0.035704
# report_week                                          0.087083
# calls_month_1_away                                  -0.054347
# calls_month_8_away                                   0.276012
# sin_report_week                                      0.082245
# cos_report_week                                     -0.092021
# calls_month_7_away                                   0.154990
# calls_month_4_away                                   0.000961
# calls_month_2_away                                   0.116802
# calls_month_5_away                                   0.158481
# report_week_total_calls                              0.167226
# report_week_total_calls_divergence                   0.171958
# calls_month_3_away                                   0.266379
# report_month                                              NaN
#
#                                     pct_delta_mean_7_forward  \
# calls_month_6_away                                 -0.111306
# report_week                                         0.163587
# calls_month_1_away                                 -0.109907
# calls_month_8_away                                 -0.011257
# sin_report_week                                     0.158013
# cos_report_week                                    -0.167980
# calls_month_7_away                                 -0.032287
# calls_month_4_away                                  0.195611
# calls_month_2_away                                  0.021087
# calls_month_5_away                                  0.034173
# report_week_total_calls                             0.015713
# report_week_total_calls_divergence                  0.021841
# calls_month_3_away                                  0.082380
# report_month                                             NaN
#
#                                     pct_delta_max_7_forward  \
# calls_month_6_away                                -0.072348
# report_week                                        0.219152
# calls_month_1_away                                -0.145806
# calls_month_8_away                                 0.175174
# sin_report_week                                    0.210036
# cos_report_week                                   -0.226890
# calls_month_7_away                                 0.062605
# calls_month_4_away                                 0.124843
# calls_month_2_away                                 0.073448
# calls_month_5_away                                 0.145984
# report_week_total_calls                            0.097497
# report_week_total_calls_divergence                 0.106266
# calls_month_3_away                                 0.182776
# report_month                                            NaN
#
#                                     mean_rise_7_forward  max_rise_7_forward  \
# calls_month_6_away                            -0.163239           -0.173490
# report_week                                    0.141458            0.214707
# calls_month_1_away                            -0.162189           -0.196430
# calls_month_8_away                            -0.134472           -0.047150
# sin_report_week                                0.149460            0.223815
# cos_report_week                               -0.131064           -0.201229
# calls_month_7_away                            -0.133901           -0.122339
# calls_month_4_away                             0.104950            0.239488
# calls_month_2_away                             0.042467           -0.062945
# calls_month_5_away                            -0.004318           -0.070971
# report_week_total_calls                       -0.030191           -0.099219
# report_week_total_calls_divergence            -0.022626           -0.089973
# calls_month_3_away                             0.044830           -0.031539
# report_month                                        NaN                 NaN
#
#                                     month
# calls_month_6_away                      2
# report_week                             2
# calls_month_1_away                      2
# calls_month_8_away                      2
# sin_report_week                         2
# cos_report_week                         2
# calls_month_7_away                      2
# calls_month_4_away                      2
# calls_month_2_away                      2
# calls_month_5_away                      2
# report_week_total_calls                 2
# report_week_total_calls_divergence      2
# calls_month_3_away                      2
# report_month                            2

# %%
df_model[df_model.report_month==5].plot(x='calls_month_3_away', y='value_delta_max_30_forward', kind='scatter')
# Out:
# <Axes: xlabel='calls_month_3_away', ylabel='value_delta_max_30_forward'>

# %%
df_model[df_model.report_month==6].plot(x='calls_month_6', y='pct_delta_mean_30_forward', kind='scatter')
# Out:
# /Users/thomaspile/anaconda3/lib/python3.10/site-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning:
#
# No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
# <Axes: xlabel='calls_month_6', ylabel='pct_delta_mean_30_forward'>

# %%
df_model[df_model.report_month==2].plot(x='season1_05', y='pct_delta_mean_30_forward', kind='scatter')
# Out:
# /Users/thomaspile/anaconda3/lib/python3.10/site-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning:
#
# No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
# <Axes: xlabel='season1_05', ylabel='pct_delta_mean_30_forward'>

# %%
df_model[df_model.report_month==2].plot(x='calls_month_3_away', y='pct_delta_mean_30_forward', kind='scatter')
# Out:
# <Axes: xlabel='calls_month_3_away', ylabel='pct_delta_mean_30_forward'>

# %%
df_model[df_model.report_month==2].plot(x='season1_05_divergence', y='pct_delta_mean_30_forward', kind='scatter')
# Out:
# <Axes: xlabel='season1_05_divergence', ylabel='pct_delta_mean_30_forward'>

# %%
df_2 = df_model[df_model.report_month==2][['report_year','report_week', 'season1_05', 'season1_05_divergence', 'pct_delta_mean_30_forward']]

# %%
df_2.plot(x='season1_05', y='season1_05_divergence', kind='scatter')
# Out:
# /Users/thomaspile/anaconda3/lib/python3.10/site-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning:
#
# No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
# <Axes: xlabel='season1_05', ylabel='season1_05_divergence'>

# %%
df_model.plot(x='season1_03_divergence', y='value_delta_mean_30_forward', kind='scatter')
# Out:
# /Users/thomaspile/anaconda3/lib/python3.10/site-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning:
#
# No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
# <Axes: xlabel='season1_03_divergence', ylabel='value_delta_mean_30_forward'>

# %%
df_model.plot(x='season1_03_divergence', y='value_delta_mean_30_forward', kind='scatter')

# %%
df_model.plot(x='cos_report_week', y='value_delta_mean_30_forward', kind='scatter')
# Out:
# <Axes: xlabel='cos_report_week', ylabel='value_delta_mean_30_forward'>

# %%
df_model.plot(x='cos_report_week', y='mean_30_forward', kind='scatter')
# Out:
# <Axes: xlabel='cos_report_week', ylabel='mean_30_forward'>

# %%
df_model.plot(x='report_week_total_calls', y='delta_mean_30_forward', kind='scatter')
# Out:
# /Users/thomaspile/anaconda3/lib/python3.10/site-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning:
#
# No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
# <Axes: xlabel='report_week_total_calls', ylabel='delta_mean_30_forward'>

# %%
years = [2020, 2021, 2022, 2023]
df_recent = df_yearweek_total_calls[df_yearweek_total_calls.report_year.isin(years)]
df_recent
# Out:
#             date  report_year  report_week  report_week_total_calls
# 984   2020-01-09         2020            1                   -54237
# 985   2020-01-16         2020            2                   -56006
# 986   2020-01-23         2020            3                   -57034
# 987   2020-01-30         2020            4                   -54876
# 988   2020-02-06         2020            5                   -52332
# ...          ...          ...          ...                      ...
# 1187  2023-12-01         2023           48                    -9890
# 1188  2023-12-08         2023           49                   -11409
# 1189  2023-12-15         2023           50                   -11225
# 1190  2023-12-22         2023           51                    -5420
# 1191  2023-12-29         2023           52                    -5262
#
# [208 rows x 4 columns]

# %%
_, ax = plt.subplots(figsize=(12, 7))

for year in years:
    df = df_yearweek_total_calls[df_yearweek_total_calls.report_year == year]
    ax.plot(df['report_week'], df['report_week_total_calls'], label=year)
ax.legend()

# %%
df_calls.pivot_table(index='report_week', columns='futures_month', values='unfixed_sale')

# %%
pd.to_datetime(df_calls['month']).dt.isocalendar()

# %%
df_calls.groupby('date').month.count().reset_index().sort_values('date')

# %%
df_calls[df_calls.date=='2024-06-07']

# %%
df_calls.groupby('date').month.nunique().reset_index().sort_values('date')

# %%
df_calls.groupby(['report_week', 'month']).unfixed_sale.mean()
